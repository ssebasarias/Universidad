# %% [markdown]
# ![Captura de Pantalla 2023-04-13 a la(s) 5.54.38 p. m..png](data:image/png;base64,...)

# %% [markdown]
# # <center>**Intervalos de Confianza**

# %% [markdown]
# # **¿Qué es un Intervalo de Confianza?**
#
# Un intervalo de confianza es un rango de valores, calculado a partir de una muestra estadística, que es muy probable que contenga el verdadero valor de un parámetro desconocido de la población.

# %% [markdown]
# ## **Ejemplo con 'Price Each':**
#
# Digamos que calculamos que el precio promedio de cada unidad del Producto 1 es de $50 basado en nuestra muestra de datos. Un intervalo de confianza del 95% podría decirnos que estamos un 95% seguros de que el verdadero precio promedio de cada unidad del Producto 1 en toda la población está entre $45 y $55.

# %% [markdown]
# # **¿Para qué Sirve un Intervalo de Confianza?**
#
# * **Capturar Incertidumbre:** Nos ayuda a entender el rango dentro del cual el verdadero valor del parámetro podría residir, dándonos una medida de la incertidumbre asociada con nuestras estimaciones.
#
# * **Toma de Decisiones Empresariales:** En el contexto de nuestro ejemplo, si sabemos el intervalo de confianza para el precio de cada unidad del Producto 1, podemos tomar decisiones más fundamentadas sobre cómo fijar nuestros propios precios, crear ofertas y evaluar la rentabilidad.

# %% [markdown]
# # **Conceptos Clave en Intervalos de Confianza**

# %% [markdown]
# 1. **Parámetro de la Población:** El valor numérico que resume o representa una característica particular de toda la población.
#
# 2. **Estimador Puntual:** Un único valor calculado a partir de la muestra que se utiliza como una estimación del parámetro de la población.
#
# 3. **Muestra y Población:** Es crucial entender la diferencia entre una muestra (un subconjunto de la población) y la población completa para interpretar correctamente un intervalo de confianza.
#
# 4. **Nivel de Confianza:** El grado de certeza o confianza que queremos tener en nuestras estimaciones, generalmente expresado como un porcentaje (como el 95% o el 99%).
#
# 5. **Margen de Error:** El margen de error es una medida que indica cuánto podría variar nuestra estimación si tomáramos diferentes muestras. En otras palabras, es el "colchón" que se añade y se resta a nuestro estimador puntual (como la media muestral) para obtener un rango en el cual es probable que se encuentre el verdadero parámetro de la población.
#
# ## **Diferencia Clave**
# * **Nivel de Confianza:** Es una medida de **certeza** sobre la inclusión del verdadero valor en el intervalo.
# * **Margen de Error:** Es una medida de **precisión** que indica cuán cerca estamos de estimar el verdadero valor de la población.
#
# 6. **Error Estándar:** Se refiere a una medida de la variabilidad del estimador puntual. Esta medida se emplea en el cálculo del margen de error.
#
# 7. **Valor Crítico (Z o t):** Este valor se deriva de la distribución de probabilidad que el analista está utilizando, generalmente una distribución Z o t. Está directamente relacionado con el nivel de confianza que el analista desea para el intervalo de confianza.
#
# 9. **Intervalo Bilateral y Unilateral:** Un intervalo de confianza puede clasificarse como bilateral o unilateral. Un intervalo bilateral considera tanto valores por encima como por debajo del estimador puntual, mientras que un intervalo unilateral se centra solo en una dirección.
#
# 10. **Interpretación:** La habilidad para interpretar un intervalo de confianza es fundamental. Por ejemplo, un intervalo de confianza del 95% sugiere que, si se toman múltiples muestras y se construye un intervalo de confianza para cada una, se espera que aproximadamente el 95% de esos intervalos contengan el verdadero parámetro de la población.
#
# 11. **Aplicación Práctica:** Es importante entender cómo se utilizan los intervalos de confianza en contextos prácticos, tales como en los ámbitos empresariales, médicos o políticos.

# %% [markdown]
# # **Tipos de Intervalos de Confianza**

# %% [markdown]
# ## **Intervalos de Confianza cuando la Desviación Estándar de la Población es Conocida**
# * Intervalo Z para la Media de la Población
# * Intervalo Z para la Diferencia de Medias entre Dos Poblaciones
#
# ## **Intervalos de Confianza cuando la Desviación Estándar de la Población NO es Conocida**
#
# * Intervalo t para la Media de la Población
# * Intervalo para la Proporción de la Población
# * Intervalo para la Varianza o Desviación Estándar de la Población
# * Intervalo t para la Diferencia de Medias entre Dos Poblaciones
# * Intervalo para la Diferencia de Proporciones entre Dos Poblaciones

# %% [markdown]
# ## **Intervalos de Confianza cuando la Desviación Estándar de la Población es Conocida**
#
# 1. **Intervalo Z para la Media de la Población**
#
# **Media Muestral ($\bar{x}$):** Esta es la media aritmética de todos los elementos en la muestra.
#
# **Desviación Estándar de la Población ($\sigma$):** Este es un parámetro conocido que indica la variabilidad de la población completa.
#
# **Tamaño de la Muestra ($n$):** Este es el número total de observaciones en la muestra.
#
# **Nivel de Confianza:** Este es el grado de certeza que se desea para el intervalo. Comúnmente se usa un nivel de confianza del 95%.

# %% [markdown]
# # <center>**Calculo de Intervalos de Confianza con desv. estándar conocida para la media**<center>

# %% [markdown]
# Cuando la desviación estándar (σ) de la población es conocida, se puede usar un intervalo de confianza Z para estimar un parámetro poblacional.

# %% [markdown]
# ## **Bases Teóricas**
# * **Distribución Normal:** Si la muestra es lo suficientemente grande (por ejemplo, n > 30 según la regla general), según el Teorema del Límite Central, la distribución muestral de la media será aproximadamente normal.
#
# * **Desviación Estándar Conocida:** En este caso, conocemos la desviación estándar de la población (σ).
#
# * **Estimador Puntual:** La media de la muestra ($\bar{x}$) es un "estimador puntual" de la media de la población (μ).

# %% [markdown]
# ## **Características de la distribución Normal**
#
# Con base en lo que observamos en las diapositivas anteriores, y basados en los criterios de la primera y segunda derivadas para la función n(x; μ, σ), listamos las siguientes propiedades de la distribución de probabilidad normal:
#
#   1.  La moda, que es el punto sobre el eje horizontal donde la curva tiene su punto máximo, ocurre en x = μ.
#   2.  La curva es simétrica alrededor de un eje vertical a través de la media μ.
#   3.  La curva tiene sus puntos de inflexión en x=μ±σ, es cóncava hacia abajo si           μ – σ < X < μ + σ, y es cóncava hacia arriba en otro caso.
#   4. La curva normal se aproxima al eje horizontal de manera asintótica, conforme nos alejamos de la media en cualquier dirección.
#   5. El área total bajo la curva y sobre el eje horizontal es igual a uno.
#
# ![Captura de Pantalla 2023-03-02 a la(s) 7.35.54 p. m..png](data:image/png;base64,...)

# %% [markdown]
# ## **Tabla de la Distribución Normal**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Valores críticos para diferentes niveles de confianza**
#
# <table border="1">
#   <tr>
#     <th>Nivel de Confianza</th>
#     <th>Z<sub>&alpha;/2</sub></th>
#   </tr>
#   <tr>
#     <td>90%</td>
#     <td>1.645</td>
#   </tr>
#   <tr>
#     <td>95%</td>
#     <td>1.960</td>
#   </tr>
#   <tr>
#     <td>99%</td>
#     <td>2.576</td>
#   </tr>
#   <tr>
#     <td>99.9%</td>
#     <td>3.291</td>
#   </tr>
# </table>

# %% [markdown]
# # **Fórmulas**
#
# * **Error Estándar (SE):** El error estándar es una medida de cuánto se espera que varíe la media de la muestra en torno a la media de la población. Se calcula como:
#
# <center>$\text{SE} = \frac{\sigma}{\sqrt{n}}$</center>
#
# * **Margen de Error (E):** El margen de error se calcula multiplicando el valor Z correspondiente al nivel de confianza deseado ($Z_{\alpha/2}$) por el error estándar:
#
#
# <center>​$\text{E} = Z_{\alpha/2} \times \text{SE}$</center>
#
# * **Límites del Intervalo:** Finalmente, se calculan los límites superior e inferior del intervalo sumando y restando el margen de error a la media de la muestra:
#
# <center>$\text{Límite Inferior} = \bar{x} - E$</center>
#
# <center>$\text{Límite Superior} = \bar{x} + E$</center>

# %% [markdown]
# # **Ejercicio 1: Tiempo de Carga de Página Web**
# Una empresa de tecnología que ofrece soluciones de hosting quiere medir el tiempo de carga de las páginas web de sus clientes. Después de medir el tiempo de carga de una muestra de 50 páginas web, la empresa encuentra que el tiempo medio de carga es de 2.3 segundos. La desviación estándar conocida del tiempo de carga es de 0.5 segundos.
#
# Calcule un intervalo de confianza del 95% para el tiempo medio de carga de todas las páginas web alojadas por la empresa.

# %%
from scipy.stats import norm

def calcular_intervalo_confianza(media_muestral, desviacion_poblacional, tamano_muestra, nivel_confianza):
    # Calcular el valor crítico de Z usando el nivel de confianza
    valor_critico = norm.ppf(1 - (1 - nivel_confianza) / 2)

    # Calcular el error estándar
    error_estandar = desviacion_poblacional / (tamano_muestra ** 0.5)

    # Calcular los límites del intervalo de confianza
    limite_inferior = media_muestral - valor_critico * error_estandar
    limite_superior = media_muestral + valor_critico * error_estandar

    return limite_inferior, limite_superior

# %%
# Ejercicio 1
nivel_confianza_1 = 0.95
media_muestral_1 = 2.3
desviacion_poblacional_1 = 0.5
tamano_muestra_1 = 50

limite_inferior_1, limite_superior_1 = calcular_intervalo_confianza(media_muestral_1, desviacion_poblacional_1, tamano_muestra_1, nivel_confianza_1)
print(f"Ejercicio 1: Intervalo de confianza del 95%: ({limite_inferior_1}, {limite_superior_1})")

# %% [markdown]
# # **Ejercicio 2: Tasa de Abandono del Carrito de Compras**
# Una tienda de comercio electrónico tiene una tasa de abandono del carrito de compras del 65% basada en una muestra de 100 transacciones. La desviación estándar de la población es conocida y es del 5%.
#
# Calcule un intervalo de confianza del 90% para la tasa de abandono del carrito de compras en toda la tienda.

# %%
nivel_confianza_2 = 0.9
media_muestral_2 = 65
desviacion_poblacional_2 = 5
tamano_muestra_2 = 100

limite_inferior_2, limite_superior_2 = calcular_intervalo_confianza(media_muestral_2, desviacion_poblacional_2, tamano_muestra_2, nivel_confianza_2)
print(f"Ejercicio 2: Intervalo de confianza del 90%: ({limite_inferior_2}, {limite_superior_2})")

# %% [markdown]
# # **Ejercicio 3: Duración de las Sesiones en una Aplicación**
# Una aplicación de juegos desea conocer la duración media de las sesiones de sus usuarios. De 200 sesiones seleccionadas al azar, la duración media es de 40 minutos. Se sabe que la desviación estándar de la población es de 8 minutos.
#
# Calcula un intervalo de confianza del 99% para la duración media de las sesiones en la aplicación.

# %%
nivel_confianza_3 = 0.99
media_muestral_3 = 40
desviacion_poblacional_3 = 8
tamano_muestra_3 = 200

limite_inferior_3, limite_superior_3 = calcular_intervalo_confianza(media_muestral_3, desviacion_poblacional_3, tamano_muestra_3, nivel_confianza_3)
print(f"Ejercicio 3: Intervalo de confianza del 99%: ({limite_inferior_3}, {limite_superior_3})")
